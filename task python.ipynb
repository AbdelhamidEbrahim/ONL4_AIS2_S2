# %%
# MY_name = "Abdelhamid Ebrahim Abdelhamid"
email = "Amit_ml@gmail.edu"

# %%
print(f"the number of @ in string is: {email.count('@')} and the number of . in string is: {email.count('.')}")
if email.count("@") != 1 or "." not in email.split("@")[1]:
    print("Invalid email")
# Out:
# the number of @ in string is: 1 and the number of . in string is: 1

# %%
print(f"The username is: {email.split('@')[0]}")
# Out:
# The username is: Amit_ml

# %%
print(f"The domain is: {email.split('@')[1].split('.')[0]}")
# Out:
# The domain is: gmail

# %%
if email.endswith(".com"):
    print("Commercial Domain")
elif email.endswith(".edu"):
    print("Educational Domain")
else:
    print("Other Domain")
# Out:
# Educational Domain

# %%
Encoded_Message= "###!!@mocleW EPGTQ!!!6789"

# %%
print(Encoded_Message[6:-7]) 

print(Encoded_Message[6:-12][::-1])

print(Encoded_Message[6:-12][::-1] + " " + Encoded_Message[-11:-7])
# Out:
# mocleW EPGTQ
#  Welcom
#  Welcom PGTQ

# %%
Enc_Msg= "&&&**$gnirtS PLIO!!@1234"
print(Enc_Msg[6:-7])
# Out:
# gnirtS PLIO

# %%
print(Enc_Msg[6:-11][::-1])
# Out:
#  String

# %%
Target = "gnirtS PLIO"
word1, word2 = Target.split()
word1 = word1[::-1]   
word2 = word2.replace("I", "E").replace("O", "U")
print(word1, word2)
# Out:
# String PLEU

# %%
E_Message= "##$$$@!yalpstcejorp EPUVT****9887"
print(E_Message[7:-8])
# Out:
# yalpstcejorp EPUVT

# %%
print(E_Message[7:-14][::-1])
# Out:
# projectsplay

# %%
Target = "yalpstcejorp EPUVT"
word1, word2 = Target.split()
word1 = word1[::-1]   
word2 = word2.replace("E", "A").replace("U", "O")
print(word1, word2)
# Out:
# projectsplay APOVT
